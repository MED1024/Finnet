# %%
import numpy as np
import pandas as pd
import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import catboost as cat
from catboost import CatBoostClassifier
import xgboost as xgb

# %% [markdown]
# ## Загрузим данные

# %%
# %%time
edges = pd.read_csv('./edges.csv')
ids = pd.read_csv('./ids.csv')
vertices = pd.read_csv('./vertices.csv')
# Out:
# Wall time: 2.84 s

# %%
vertices['main_okved'] = vertices['main_okved'].astype(str)

# %%
np.random.seed(7777)

# %% [markdown]
# # Визуализация

# %% [markdown]
# ## Обучим модель

# %%
result = pd.DataFrame(columns=['id_1', 'id_2'])

# %%
# для каждой вершины из ids с помощью catboost найдем 1000 самых вероятных ребер
for i in tqdm.tqdm(ids.id):
    # соберем датасет из всех возможных вершин
    # вершины имеющие в исходных данных ребро с i обозначим 1, остальные 0
    # учтем то, что вершина i может быть как среди id_1, так и среди id_2
    df1 = edges[edges['id_1'] == i].reset_index()
    df2 = edges[edges['id_2'] == i].reset_index()

    df = df1[['id_2', 'id_1']].rename(columns={'id_1':'id_2', 'id_2':'id_1'}).append(df2[['id_1', 'id_2']])
    df['target'] = 1
    
    df = vertices.set_index('id').join(df.set_index('id_1')['target']).fillna(0)
    
    
    X = df[['main_okved', 'region_code', 'company_type']]
    y = df['target']
    
    model = CatBoostClassifier(iterations=600, verbose=False)
    cat_features = [0,1,2] # все признаки категориальные
    
    model.fit(X, y, cat_features)

    preds = model.predict_proba(X)[:,1]

    df['preds'] = preds
    df['id_2'] = i
    
    # возьмем первую 1000 предсказанных ребер, исключив те, про которые мы уже знали
    res = df[df['target'] != 1].sort_values(by='preds', ascending=False).iloc[:1000].reset_index()[['id', 'id_2']]
    res.columns = ['id_1', 'id_2']
    
    result = result.append(res, ignore_index=True, sort=False)
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]
#
#   1%|▊                                                                              | 1/100 [05:24<8:55:06, 324.31s/it]
#
#   2%|█▌                                                                             | 2/100 [10:52<8:51:32, 325.43s/it]
#
#   3%|██▎                                                                            | 3/100 [16:24<8:49:34, 327.57s/it]
#
#   4%|███▏                                                                           | 4/100 [21:54<8:45:09, 328.22s/it]
#
#   5%|███▉                                                                           | 5/100 [27:09<8:33:17, 324.19s/it]
#
#   6%|████▋                                                                          | 6/100 [32:18<8:21:00, 319.79s/it]
#
#   7%|█████▌                                                                         | 7/100 [37:24<8:09:00, 315.49s/it]
#
#   8%|██████▎                                                                        | 8/100 [42:34<8:01:01, 313.72s/it]
#
#   9%|███████                                                                        | 9/100 [47:40<7:52:24, 311.48s/it]
#
#  10%|███████▊                                                                      | 10/100 [52:41<7:42:25, 308.28s/it]
#
#  11%|████████▌                                                                     | 11/100 [58:41<8:00:33, 323.97s/it]
#
#  12%|█████████                                                                   | 12/100 [1:04:40<8:10:29, 334.43s/it]
#
#  13%|█████████▉                                                                  | 13/100 [1:10:29<8:11:27, 338.94s/it]
#
#  14%|██████████▋                                                                 | 14/100 [1:16:11<8:06:51, 339.67s/it]
#
#  15%|███████████▍                                                                | 15/100 [1:21:05<7:41:54, 326.05s/it]
#
#  16%|████████████▏                                                               | 16/100 [1:26:08<7:26:46, 319.13s/it]
#
#  17%|████████████▉                                                               | 17/100 [1:31:13<7:15:29, 314.82s/it]
#
#  18%|█████████████▋                                                              | 18/100 [1:36:34<7:12:51, 316.73s/it]
#
#  19%|██████████████▍                                                             | 19/100 [1:41:51<7:07:42, 316.82s/it]
#
#  89%|█████████████████████████████████████████████████████████████████████▍        | 89/100 [7:48:36<57:02, 311.18s/it]
#
#  90%|██████████████████████████████████████████████████████████████████████▏       | 90/100 [7:53:50<52:01, 312.13s/it]
#
#  91%|██████████████████████████████████████████████████████████████████████▉       | 91/100 [7:59:11<47:12, 314.72s/it]
#
#  92%|███████████████████████████████████████████████████████████████████████▊      | 92/100 [8:04:18<41:38, 312.36s/it]
#
#  93%|████████████████████████████████████████████████████████████████████████▌     | 93/100 [8:09:41<36:50, 315.73s/it]
#
#  94%|█████████████████████████████████████████████████████████████████████████▎    | 94/100 [8:14:59<31:38, 316.38s/it]
#
#  95%|██████████████████████████████████████████████████████████████████████████    | 95/100 [8:20:07<26:09, 313.96s/it]
#
#  96%|██████████████████████████████████████████████████████████████████████████▉   | 96/100 [8:25:24<20:58, 314.72s/it]
#
#  97%|███████████████████████████████████████████████████████████████████████████▋  | 97/100 [8:30:22<15:29, 309.80s/it]
#
#  98%|████████████████████████████████████████████████████████████████████████████▍ | 98/100 [8:35:21<10:12, 306.46s/it]
#
#  99%|█████████████████████████████████████████████████████████████████████████████▏| 99/100 [8:40:28<05:06, 306.69s/it]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [8:45:34<00:00, 315.34s/it]

# %% [markdown]
# ## Результат готов к отправке

# %%
result.to_csv('submission4000.csv', index = False)

# %%
res
# Out:
#         id_1     id_2
# 0     537164  1244877
# 1    1390385  1244877
# 2      99199  1244877
# 3     591239  1244877
# 4     483817  1244877
# ..       ...      ...
# 995   287342  1244877
# 996   217663  1244877
# 997   703343  1244877
# 998   287365  1244877
# 999  1386240  1244877
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Второй вариант обучения

# %%
result = pd.DataFrame(columns=['id_1', 'id_2'])

# %%
# для каждой вершины из ids с помощью catboost найдем 1000 самых вероятных ребер
for i in tqdm.tqdm(ids.id):
    # соберем датасет из всех возможных вершин
    # вершины имеющие в исходных данных ребро с i обозначим 1, остальные 0
    # учтем то, что вершина i может быть как среди id_1, так и среди id_2
    df1 = edges[edges['id_1'] == i].reset_index()
    df2 = edges[edges['id_2'] == i].reset_index()

    df = df1[['id_2', 'id_1']].rename(columns={'id_1':'id_2', 'id_2':'id_1'}).append(df2[['id_1', 'id_2']])
    df['target'] = 1
    
    df = vertices.set_index('id').join(df.set_index('id_1')['target']).fillna(0)
    
    
    X = df[['main_okved', 'region_code', 'company_type']]
    y = df['target']
    
    model = CatBoostClassifier(iterations=300, verbose=False,loss_function='MultiClass',learning_rate=0.03, eval_metric='Accuracy'
)
    cat_features = [0,1,2] # все признаки категориальные
    
    model.fit(X, y, cat_features)

    preds = model.predict_proba(X)[:,1]

    df['preds'] = preds
    df['id_2'] = i
    
    # возьмем первую 1000 предсказанных ребер, исключив те, про которые мы уже знали
    res = df[df['target'] != 1].sort_values(by='preds', ascending=False).iloc[:1000].reset_index()[['id', 'id_2']]
    res.columns = ['id_1', 'id_2']
    
    result = result.append(res, ignore_index=True, sort=False)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [4:29:05<00:00, 161.45s/it]

# %%
result
# Out:
#            id_1     id_2
# 0        188225   524354
# 1       1195897   524354
# 2       1447932   524354
# 3       1434000   524354
# 4       1295314   524354
# ...         ...      ...
# 179995   165027  1244877
# 179996   957332  1244877
# 179997   982526  1244877
# 179998   340093  1244877
# 179999  1092218  1244877
#
# [180000 rows x 2 columns]

# %%
result
# Out:
#           id_1     id_2
# 0       188225   524354
# 1      1195897   524354
# 2      1447932   524354
# 3      1434000   524354
# 4      1295314   524354
# ...        ...      ...
# 99995  1493161  1244877
# 99996  1244903  1244877
# 99997    13308  1244877
# 99998   139347  1244877
# 99999  1117562  1244877
#
# [100000 rows x 2 columns]
